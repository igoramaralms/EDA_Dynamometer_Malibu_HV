# %% [markdown]
# # Libraries

# %%
# %%capture

# !pip install numpy
# !pip install pybamm
# !pip install scikit-learn
# !pip install fastsim

# Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
import glob
import os
import math
#import fastsim
#import pybamm

# %% [markdown]
# ## EDA

# %%
path = "HIGHWAY_TEST"

# Lista todos os arquivos .txt
txt_list = glob.glob(os.path.join(path, "*.txt"))

dfs = []

# %%
for txt in txt_list:
    # Extrai TEST ID
    test_id = int(os.path.basename(txt).split()[0])
    
    # Lê o arquivo .txt
    df = pd.read_csv(txt, sep="\t")
    
    # Adiciona coluna "Test_id"
    df["Test_id"] = test_id
    
    dfs.append(df)

# %%
# Concatena tudo
df = pd.concat(dfs, ignore_index=True)

# %%
# Coloca "Test_id" como a primeira coluna e ordena para começar no primeiro "Test_id"
columns = ["Test_id"] + [col for col in df.columns if col != "Test_id"]
df = df[columns]

df = df.sort_values(by="Test_id").reset_index(drop=True)

# %%
df.head(5)
# Out:
#     Test_id  Time[sec]  Dyno_Speed[mph]  Dyno_Tractive_Effort[N]  \
# 0  61302061       -9.0           -0.001                   -2.803
# 1  61302061       -8.9           -0.002                   -2.890
# 2  61302061       -8.8           -0.001                   -2.825
# 3  61302061       -8.7           -0.002                   -2.738
# 4  61302061       -8.6           -0.001                   -2.846
#
#    Test_Cell_RH[%]  Test_Cell_Temp[C]  Phase_#  Engine_Oil_Temp[C]  \
# 0           49.639             21.908      0.0              81.599
# 1           49.638             21.909      0.0              81.599
# 2           49.639             21.910      0.0              81.621
# 3           49.639             21.910      0.0              81.642
# 4           49.640             21.910      0.0              81.664
#
#    Engine_Coolant_Temp[C]  Engine_Speed[rpm]  HV_Battery_Current[A]  \
# 0                    84.0             872.50                 -8.226
# 1                    84.0             872.25                 -8.440
# 2                    84.0             854.50                 -8.604
# 3                    84.0             860.75                 -8.939
# 4                    84.0             853.25                 -8.823
#
#    HV_Battery_Voltage[V]  Fuel_Flow_FuelScale[cc/s]
# 0                110.507                      0.304
# 1                110.524                      0.304
# 2                110.539                      0.304
# 3                110.565                      0.304
# 4                110.564                      0.304

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46653 entries, 0 to 46652
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Test_id                    46653 non-null  int64
#  1   Time[sec]                  46653 non-null  float64
#  2   Dyno_Speed[mph]            46653 non-null  float64
#  3   Dyno_Tractive_Effort[N]    46653 non-null  float64
#  4   Test_Cell_RH[%]            46653 non-null  float64
#  5   Test_Cell_Temp[C]          46653 non-null  float64
#  6   Phase_#                    46653 non-null  float64
#  7   Engine_Oil_Temp[C]         46653 non-null  float64
#  8   Engine_Coolant_Temp[C]     46653 non-null  float64
#  9   Engine_Speed[rpm]          46653 non-null  float64
#  10  HV_Battery_Current[A]      46653 non-null  float64
#  11  HV_Battery_Voltage[V]      46653 non-null  float64
#  12  Fuel_Flow_FuelScale[cc/s]  46653 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 4.6 MB

# %%
df.isnull().sum()
# Out:
# Test_id                      0
# Time[sec]                    0
# Dyno_Speed[mph]              0
# Dyno_Tractive_Effort[N]      0
# Test_Cell_RH[%]              0
# Test_Cell_Temp[C]            0
# Phase_#                      0
# Engine_Oil_Temp[C]           0
# Engine_Coolant_Temp[C]       0
# Engine_Speed[rpm]            0
# HV_Battery_Current[A]        0
# HV_Battery_Voltage[V]        0
# Fuel_Flow_FuelScale[cc/s]    0
# dtype: int64

# %%
print("Total de valores nulos:", df.isnull().sum().sum())
# Out:
# Total de valores nulos: 0

# %%
df.shape
# Out:
# (46653, 13)

# %%
df["Test_id"].value_counts().sort_index()
# Out:
# Test_id
# 61302061    15551
# 61302075    15551
# 61302099    15551
# Name: count, dtype: int64

# %%
df.describe().T
# Out:
#                              count          mean         std           min  \
# Test_id                    46653.0  6.130208e+07   15.691638  6.130206e+07
# Time[sec]                  46653.0  7.675000e+02  448.923512 -1.000000e+01
# Dyno_Speed[mph]            46653.0  4.755947e+01   11.681238 -1.780000e-01
# Dyno_Tractive_Effort[N]    46653.0  2.196503e+02  541.875451 -3.345964e+03
# Test_Cell_RH[%]            46653.0  2.726923e+01    7.587114  1.694400e+01
# Test_Cell_Temp[C]          46653.0  1.934255e+01   18.612679 -8.077000e+00
# Phase_#                    46653.0  1.475789e+00    0.530755  0.000000e+00
# Engine_Oil_Temp[C]         46653.0  8.818129e+01    4.322323  0.000000e+00
# Engine_Coolant_Temp[C]     46653.0  8.524324e+01    2.290608  7.800000e+01
# Engine_Speed[rpm]          46653.0  1.387640e+03  222.989853  0.000000e+00
# HV_Battery_Current[A]      46653.0 -4.198638e-01   19.556207 -1.065060e+02
# HV_Battery_Voltage[V]      46653.0  1.100821e+02    2.498346  0.000000e+00
# Fuel_Flow_FuelScale[cc/s]  46653.0  1.101241e+00    0.583572  0.000000e+00
#
#                                     25%           50%           75%  \
# Test_id                    6.130206e+07  6.130208e+07  6.130210e+07
# Time[sec]                  3.787000e+02  7.675000e+02  1.156300e+03
# Dyno_Speed[mph]            4.494500e+01  4.911400e+01  5.555400e+01
# Dyno_Tractive_Effort[N]    8.789200e+01  2.574520e+02  4.223410e+02
# Test_Cell_RH[%]            2.063800e+01  2.462800e+01  3.372100e+01
# Test_Cell_Temp[C]         -4.938000e+00  2.558600e+01  3.799900e+01
# Phase_#                    1.000000e+00  1.000000e+00  2.000000e+00
# Engine_Oil_Temp[C]         8.548900e+01  8.856500e+01  9.276700e+01
# Engine_Coolant_Temp[C]     8.300000e+01  8.500000e+01  8.700000e+01
# Engine_Speed[rpm]          1.293000e+03  1.413500e+03  1.493750e+03
# HV_Battery_Current[A]     -4.777000e+00  4.262000e+00  4.635000e+00
# HV_Battery_Voltage[V]      1.090640e+02  1.098320e+02  1.108180e+02
# Fuel_Flow_FuelScale[cc/s]  7.680000e-01  1.102000e+00  1.389000e+00
#
#                                     max
# Test_id                    6.130210e+07
# Time[sec]                  1.545000e+03
# Dyno_Speed[mph]            6.028500e+01
# Dyno_Tractive_Effort[N]    5.425089e+03
# Test_Cell_RH[%]            5.048700e+01
# Test_Cell_Temp[C]          3.978900e+01
# Phase_#                    2.000000e+00
# Engine_Oil_Temp[C]         9.397700e+01
# Engine_Coolant_Temp[C]     9.500000e+01
# Engine_Speed[rpm]          3.995500e+03
# HV_Battery_Current[A]      1.329190e+02
# HV_Battery_Voltage[V]      1.222020e+02
# Fuel_Flow_FuelScale[cc/s]  4.557000e+00

# %% [markdown]
# #### Outliers

# %%
# Gera um boxplot para cada  coluna
for col in df:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot - {col}")
    plt.show()

# %%
for col in df.select_dtypes(include=np.number).columns:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    outliers = df[(df[col] < q1 - 1.5*iqr) | (df[col] > q3 + 1.5*iqr)]
    if not outliers.empty:
        print(f"Coluna {col} tem {len(outliers)} outliers")
# Out:
# Coluna Dyno_Speed[mph] tem 2725 outliers
# Coluna Dyno_Tractive_Effort[N] tem 5021 outliers
# Coluna Engine_Oil_Temp[C] tem 63 outliers
# Coluna Engine_Coolant_Temp[C] tem 52 outliers
# Coluna Engine_Speed[rpm] tem 1944 outliers
# Coluna HV_Battery_Current[A] tem 6119 outliers
# Coluna HV_Battery_Voltage[V] tem 3228 outliers
# Coluna Fuel_Flow_FuelScale[cc/s] tem 1599 outliers

# %% [markdown]
# #### Correlação

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
