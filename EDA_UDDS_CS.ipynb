# %% [markdown]
# # Libraries

# %%
# %%capture

# !pip install numpy
# !pip install pybamm
# !pip install scikit-learn
# !pip install fastsim

# Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
import glob
import os
import math
#import fastsim
#import pybamm

# %% [markdown]
# ## EDA

# %%
path = "UDDS_CS_TEST"

# Lista todos os arquivos .txt
txt_list = glob.glob(os.path.join(path, "*.txt"))

dfs = []

# %%
for txt in txt_list:
    # Extrai TEST ID
    test_id = int(os.path.basename(txt).split()[0])
    
    # Lê o arquivo .txt
    df = pd.read_csv(txt, sep="\t")
    
    # Adiciona coluna "Test_id"
    df["Test_id"] = test_id
    
    dfs.append(df)

# %%
# Concatena tudo
df = pd.concat(dfs, ignore_index=True)

# %%
# Coloca "Test_id" como a primeira coluna e ordena para começar no primeiro "Test_id"
columns = ["Test_id"] + [col for col in df.columns if col != "Test_id"]
df = df[columns]

df = df.sort_values(by="Test_id").reset_index(drop=True)

# %%
df.head(5)
# Out:
#     Test_id  Time[sec]  Dyno_Speed[mph]  Dyno_Tractive_Effort[N]  \
# 0  61302058       -7.4           -0.001                   -2.738
# 1  61302058       -7.3            0.001                   -2.782
# 2  61302058       -7.2            0.000                   -2.782
# 3  61302058       -7.1           -0.001                   -2.803
# 4  61302058       -7.0           -0.001                   -2.890
#
#    Test_Cell_RH[%]  Test_Cell_Temp[C]  Phase_#  Engine_Oil_Temp[C]  \
# 0           43.533             21.968      1.0              24.998
# 1           43.529             21.967      1.0              25.001
# 2           43.531             21.967      1.0              25.009
# 3           43.531             21.967      1.0              25.009
# 4           43.530             21.966      1.0              25.014
#
#    Engine_Coolant_Temp[C]  Engine_Speed[rpm]  HV_Battery_Current[A]  \
# 0                    25.0                0.0                  0.035
# 1                    25.0                0.0                  0.035
# 2                    25.0                0.0                  0.035
# 3                    25.0                0.0                  0.040
# 4                    25.0                0.0                  0.042
#
#    HV_Battery_Voltage[V]  Fuel_Flow_FuelScale[cc/s]
# 0                109.466                        0.0
# 1                109.467                        0.0
# 2                109.466                        0.0
# 3                109.465                        0.0
# 4                109.468                        0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41523 entries, 0 to 41522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Test_id                    41523 non-null  int64
#  1   Time[sec]                  41523 non-null  float64
#  2   Dyno_Speed[mph]            41523 non-null  float64
#  3   Dyno_Tractive_Effort[N]    41523 non-null  float64
#  4   Test_Cell_RH[%]            41523 non-null  float64
#  5   Test_Cell_Temp[C]          41523 non-null  float64
#  6   Phase_#                    41523 non-null  float64
#  7   Engine_Oil_Temp[C]         41523 non-null  float64
#  8   Engine_Coolant_Temp[C]     41523 non-null  float64
#  9   Engine_Speed[rpm]          41523 non-null  float64
#  10  HV_Battery_Current[A]      41523 non-null  float64
#  11  HV_Battery_Voltage[V]      41523 non-null  float64
#  12  Fuel_Flow_FuelScale[cc/s]  41523 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 4.1 MB

# %%
df.isnull().sum()
# Out:
# Test_id                      0
# Time[sec]                    0
# Dyno_Speed[mph]              0
# Dyno_Tractive_Effort[N]      0
# Test_Cell_RH[%]              0
# Test_Cell_Temp[C]            0
# Phase_#                      0
# Engine_Oil_Temp[C]           0
# Engine_Coolant_Temp[C]       0
# Engine_Speed[rpm]            0
# HV_Battery_Current[A]        0
# HV_Battery_Voltage[V]        0
# Fuel_Flow_FuelScale[cc/s]    0
# dtype: int64

# %%
print("Total de valores nulos:", df.isnull().sum().sum())
# Out:
# Total de valores nulos: 0

# %%
df.shape
# Out:
# (41523, 13)

# %%
df["Test_id"].value_counts().sort_index()
# Out:
# Test_id
# 61302058    13841
# 61302071    13841
# 61302095    13841
# Name: count, dtype: int64

# %%
df.describe().T
# Out:
#                              count          mean          std           min  \
# Test_id                    41523.0  6.130207e+07    15.326270  6.130206e+07
# Time[sec]                  41523.0  6.820000e+02   399.560064 -1.000000e+01
# Dyno_Speed[mph]            41523.0  1.939410e+01    14.703139 -4.210000e-01
# Dyno_Tractive_Effort[N]    41523.0  8.199640e+01  1115.815343 -3.941311e+03
# Test_Cell_RH[%]            41523.0  3.494483e+01    14.440012  1.210000e+01
# Test_Cell_Temp[C]          41523.0  1.682554e+01    17.476878 -7.983000e+00
# Phase_#                    41523.0  1.622474e+00     0.495729  0.000000e+00
# Engine_Oil_Temp[C]         41523.0  5.764360e+01    23.983464 -5.888000e+00
# Engine_Coolant_Temp[C]     41523.0  7.019611e+01    18.257542 -6.000000e+00
# Engine_Speed[rpm]          41523.0  1.252002e+03   532.350126  0.000000e+00
# HV_Battery_Current[A]      41523.0 -4.969118e-01    17.633753 -9.755700e+01
# HV_Battery_Voltage[V]      41523.0  1.114688e+02     3.722533  0.000000e+00
# Fuel_Flow_FuelScale[cc/s]  41523.0  8.701266e-01     0.813708  0.000000e+00
#
#                                     25%           50%           75%  \
# Test_id                    6.130206e+07  6.130207e+07  6.130210e+07
# Time[sec]                  3.360000e+02  6.820000e+02  1.028000e+03
# Dyno_Speed[mph]            5.201500e+00  2.140200e+01  2.728800e+01
# Dyno_Tractive_Effort[N]   -8.881150e+01  9.784000e+00  5.239170e+02
# Test_Cell_RH[%]            1.683400e+01  4.091200e+01  4.715600e+01
# Test_Cell_Temp[C]         -6.405000e+00  2.205200e+01  3.416500e+01
# Phase_#                    1.000000e+00  2.000000e+00  2.000000e+00
# Engine_Oil_Temp[C]         4.140950e+01  6.263400e+01  7.938200e+01
# Engine_Coolant_Temp[C]     6.000000e+01  8.100000e+01  8.300000e+01
# Engine_Speed[rpm]          9.737500e+02  1.383000e+03  1.569625e+03
# HV_Battery_Current[A]     -5.680000e+00  1.981000e+00  5.190000e+00
# HV_Battery_Voltage[V]      1.095030e+02  1.106620e+02  1.132140e+02
# Fuel_Flow_FuelScale[cc/s]  2.880000e-01  6.620000e-01  1.263000e+00
#
#                                     max
# Test_id                    6.130210e+07
# Time[sec]                  1.374000e+03
# Dyno_Speed[mph]            5.790800e+01
# Dyno_Tractive_Effort[N]    4.150028e+03
# Test_Cell_RH[%]            5.449900e+01
# Test_Cell_Temp[C]          3.857600e+01
# Phase_#                    2.000000e+00
# Engine_Oil_Temp[C]         8.883300e+01
# Engine_Coolant_Temp[C]     8.700000e+01
# Engine_Speed[rpm]          2.828750e+03
# HV_Battery_Current[A]      1.567550e+02
# HV_Battery_Voltage[V]      1.297240e+02
# Fuel_Flow_FuelScale[cc/s]  5.237000e+00

# %% [markdown]
# #### Outliers

# %%
# Gera um boxplot para cada  coluna
for col in df:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot - {col}")
    plt.show()

# %%
for col in df.select_dtypes(include=np.number).columns:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    outliers = df[(df[col] < q1 - 1.5*iqr) | (df[col] > q3 + 1.5*iqr)]
    if not outliers.empty:
        print(f"Coluna {col} tem {len(outliers)} outliers")
# Out:
# Coluna Dyno_Tractive_Effort[N] tem 9225 outliers
# Coluna Engine_Coolant_Temp[C] tem 1417 outliers
# Coluna Engine_Speed[rpm] tem 3921 outliers
# Coluna HV_Battery_Current[A] tem 4948 outliers
# Coluna HV_Battery_Voltage[V] tem 1660 outliers
# Coluna Fuel_Flow_FuelScale[cc/s] tem 1518 outliers

# %% [markdown]
# #### Correlação

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
